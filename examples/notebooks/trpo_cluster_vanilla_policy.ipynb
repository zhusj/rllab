# %%
from rllab.algos.cem import CEM
from rllab.algos.ddpg import DDPG
from rllab.algos.tnpg import TNPG
from rllab.algos.trpo import TRPO
from rllab.algos.vpg import VPG
from rllab.algos.batch_polopt import BatchSampler


from rllab.baselines.linear_feature_baseline import LinearFeatureBaseline
from rllab.envs.gym_env import GymEnv
from rllab.envs.normalized_env import normalize
from rllab.exploration_strategies.ou_strategy import OUStrategy
from rllab.misc.instrument import run_experiment_lite
from rllab.misc.instrument import VariantGenerator, variant
from rllab.policies.categorical_mlp_policy import CategoricalMLPPolicy
from rllab.policies.gaussian_mlp_policy import GaussianMLPPolicy
from rllab.policies.deterministic_mlp_policy import DeterministicMLPPolicy
from rllab.q_functions.continuous_mlp_q_function import ContinuousMLPQFunction
from rllab.sampler.utils import collect_data
from rllab.sampler.utils import rollout

import gym
import numpy as np
import GPy
import GPyOpt

import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
import pandas as pd


import plotly
plotly.offline.init_notebook_mode() 
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np
import pandas as pd
import copy
import pickle
from datetime import datetime

common_batch_algo_args = dict(
    n_itr=2000,
    batch_size=1000,
    max_path_length=1000,
)

import random
from operator import add, sub

# %%
class VG(VariantGenerator):

    @variant
    def env(self):
#         return ["HalfCheetah-v1","Hopper-v1","Walker2d-v1", "Swimmer-v1","InvertedPendulum-v1"]
        return ["Swimmer-v1"]
    @variant
    def total_iter(self):
#         return [1000, 200, 1000, 400, 100]
        return [400]
    @variant
    def seed(self):
        return list(range(1, 41))

# %%
### real = defualt, sim = [0.5,0.9]-[1.1,1.5]* real

############ Train in sim env ###############
def run_task(vv):
    # Please note that different environments with different action spaces may
    # require different policies. For example with a Discrete action space, a
    # CategoricalMLPPolicy works, but for a Box action space may need to use
    # a GaussianMLPPolicy (see the trpo_gym_pendulum.py example)
    print("vv: ", vv)
#     env = normalize(GymEnv(vv["env"],record_video=False, record_log=False))

    
    env_sim = normalize(GymEnv(vv["env"],record_video=False, record_log=False))
    
    op = random.choice([add, sub])
    factor = op(1, 0.1 + 0.4*np.random.random_sample())
    mb = env_sim.wrapped_env.env.env.model.body_mass
    mb = np.array(mb)
    mb = mb*factor
    env_sim.wrapped_env.env.env.model.body_mass = mb
    
    policy = GaussianMLPPolicy(
        env_spec=env_sim.spec,
        # The neural network policy should have two hidden layers, each with 32 hidden units.
        hidden_sizes=(32, 32)
    )

    baseline = LinearFeatureBaseline(env_spec=env_sim.spec)
    returns = []
    total_iter = vv["total_iter"]
    test_iter = 10
    num_iters = int(total_iter/test_iter)
    
    for i in range(0,num_iters):
        print("iter: ", i)
        
        algo = TRPO(
            env=env_sim,
            policy=policy,
            baseline=baseline,
            batch_size=4000,
            max_path_length=1000,
            n_itr=test_iter,
            discount=0.99,
            step_size=0.01,
    #         Uncomment both lines (this and the plot parameter below) to enable plotting
    #         plot=True,
        )
        algo.train()
        
        ################### Testing in GT parameter #################
        print("sim mass: ", algo.env.wrapped_env.env.env.model.body_mass)
        
        env_real = normalize(GymEnv(vv["env"],record_video=False, record_log=False))
        print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)

        algo_real = copy.deepcopy(algo)
        algo_real.env = env_real
        sampler_cls = BatchSampler
        sampler = sampler_cls(algo_real)
        sampler.start_worker()
        paths = sampler.obtain_samples(1)
        paths_returns = [sum(path["rewards"]) for path in paths]
        sampler.shutdown_worker()
        print("Real sample ave returns: \n\n\n\n\n\n !!!!!!!!!!!!!!!!!!!", np.mean(paths_returns))   
        returns.append(np.mean(paths_returns))
                
        path = rollout(env_real, algo.policy, max_path_length=1000,
                       animated=False, speedup=1)
        path["returns"] = sum(path["rewards"])
        print("rollout return: \n\n\n\n\n\n\n\n !!!!!!!!!!!!!!!!!!!!!", path["returns"] )
#         returns.append(path['returns'])
        ##############################################################
        
        
    print("returns: ", returns)
    now = datetime.now()
    save_data_filename = "SIM_returns_"+vv["env"]+"_iter_"+str(total_iter)+"_"+str(now)
    with open(save_data_filename, 'wb') as f:
        pickle.dump(returns, f)

variants = VG().variants()


for v in variants:
    run_experiment_lite(
        run_task,
        # Number of parallel workers for sampling
        n_parallel=1,
        # Only keep the snapshot parameters for the last iteration
        snapshot_mode="last",
        # Specifies the seed for the experiment. If this is not provided, a random seed
        # will be used
        seed=v["seed"],
        mode="local",
        exp_prefix = "SIM_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
        variant=v,
    #     plot=True,
    )
# Out:
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0070'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0070'  --variant_data ''  --seed '1'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0071'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0071'  --variant_data ''  --seed '2'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0072'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0072'  --variant_data ''  --seed '3'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0073'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0073'  --variant_data ''  --seed '4'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0074'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0074'  --variant_data ''  --seed '5'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0075'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0075'  --variant_data ''  --seed '6'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0076'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0076'  --variant_data ''  --seed '7'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0077'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0077'  --variant_data ''  --seed '8'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0078'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0078'  --variant_data ''  --seed '9'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0079'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0079'  --variant_data ''  --seed '10'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0080'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0080'  --variant_data ''  --seed '11'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0081'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0081'  --variant_data ''  --seed '12'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0082'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0082'  --variant_data ''  --seed '13'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0083'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0083'  --variant_data ''  --seed '14'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0084'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0084'  --variant_data ''  --seed '15'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0085'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0085'  --variant_data ''  --seed '16'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0086'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0086'  --variant_data ''  --seed '17'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0087'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0087'  --variant_data ''  --seed '18'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0088'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0088'  --variant_data ''  --seed '19'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0089'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0089'  --variant_data ''  --seed '20'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0090'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0090'  --variant_data ''  --seed '21'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0091'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0091'  --variant_data ''  --seed '22'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0092'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0092'  --variant_data ''  --seed '23'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0093'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0093'  --variant_data ''  --seed '24'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0094'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0094'  --variant_data ''  --seed '25'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0095'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0095'  --variant_data ''  --seed '26'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0096'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0096'  --variant_data ''  --seed '27'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0097'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0097'  --variant_data ''  --seed '28'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0098'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0098'  --variant_data ''  --seed '29'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0099'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0099'  --variant_data ''  --seed '30'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0100'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0100'  --variant_data ''  --seed '31'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0101'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0101'  --variant_data ''  --seed '32'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0102'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0102'  --variant_data ''  --seed '33'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0103'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0103'  --variant_data ''  --seed '34'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0104'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0104'  --variant_data ''  --seed '35'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0105'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0105'  --variant_data ''  --seed '36'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0106'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0106'  --variant_data ''  --seed '37'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0107'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0107'  --variant_data ''  --seed '38'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0108'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0108'  --variant_data ''  --seed '39'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0109'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0109'  --variant_data ''  --seed '40'  --use_cloudpickle 'True'  --n_parallel '1'

# %%
############### real = default

############## Train in real env ########################

def run_task(vv):
    # Please note that different environments with different action spaces may
    # require different policies. For example with a Discrete action space, a
    # CategoricalMLPPolicy works, but for a Box action space may need to use
    # a GaussianMLPPolicy (see the trpo_gym_pendulum.py example)
    print("vv: ", vv)
    env_real = normalize(GymEnv(vv["env"],record_video=False, record_log=False))
    
    print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
    
    mb = env_real.wrapped_env.env.env.model.body_mass
    mb = np.array(mb)
#     mb = mb*0.8
    env_real.wrapped_env.env.env.model.body_mass = mb
    print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
    
    
    policy = GaussianMLPPolicy(
        env_spec=env_real.spec,
        # The neural network policy should have two hidden layers, each with 32 hidden units.
        hidden_sizes=(32, 32)
    )

    baseline = LinearFeatureBaseline(env_spec=env_real.spec)
    returns = []
    total_iter = vv["total_iter"]
    test_iter = 10
    num_iters = int(total_iter/test_iter)
    
    for i in range(0,num_iters):
        print("iter: ", i)
        
        algo = TRPO(
            env=env_real,
            policy=policy,
            baseline=baseline,
            batch_size=4000,
            max_path_length=1000,
            n_itr=test_iter,
            discount=0.99,
            step_size=0.01,
    #         Uncomment both lines (this and the plot parameter below) to enable plotting
    #         plot=True,
        )
        algo.train()
        
        ################### Testing in GT parameter #################
        print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
        
#         env2 = copy.deepcopy(env)
#         mb = env2.wrapped_env.env.env.model.body_mass
#         mb = np.array(mb)
#         mb = mb*0.6
#         env2.wrapped_env.env.env.model.body_mass = mb

#         print("real mass: ", env2.wrapped_env.env.env.model.body_mass)

#         path = rollout(env2, policy, max_path_length=1000,
#                        animated=False, speedup=1)

        path = rollout(env_real, policy, max_path_length=1000,
                       animated=False, speedup=1)
        path["returns"] = sum(path["rewards"])
        print("returns: ", path['returns'])
        returns.append(path['returns'])
        ##############################################################
        
        
    print("returns: ", returns)
    now = datetime.now()
    save_data_filename = "REAL_returns_"+vv["env"]+"_iter_"+str(total_iter)+"_"+str(now)
    with open(save_data_filename, 'wb') as f:
        pickle.dump(returns, f)
        
    
variants = VG().variants()

for v in variants:
    print("seed: ", v["seed"])
    run_experiment_lite(
        run_task,
        # Number of parallel workers for sampling
        n_parallel=1,
        # Only keep the snapshot parameters for the last iteration
        snapshot_mode="last",
        # Specifies the seed for the experiment. If this is not provided, a random seed
        # will be used
        seed=v["seed"],
        exp_prefix = "REAL_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
        variant=v,
    #     plot=True,
    )
# Out:
# seed:  1
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0058'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0058'  --variant_data ''  --seed '1'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  2
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0059'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0059'  --variant_data ''  --seed '2'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  3
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0060'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0060'  --variant_data ''  --seed '3'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  4
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0061'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0061'  --variant_data ''  --seed '4'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  5
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0062'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0062'  --variant_data ''  --seed '5'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  6
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0063'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0063'  --variant_data ''  --seed '6'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  7
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0064'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0064'  --variant_data ''  --seed '7'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  8
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0065'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0065'  --variant_data ''  --seed '8'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  9
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0066'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0066'  --variant_data ''  --seed '9'  --use_cloudpickle 'True'  --n_parallel '1'
# seed:  10
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0067'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0067'  --variant_data ''  --seed '10'  --use_cloudpickle 'True'  --n_parallel '1'

# %%
### real = 0.6 * defualt, sim = defualt

############ Train in sim env ###############
def run_task(vv):
    # Please note that different environments with different action spaces may
    # require different policies. For example with a Discrete action space, a
    # CategoricalMLPPolicy works, but for a Box action space may need to use
    # a GaussianMLPPolicy (see the trpo_gym_pendulum.py example)
    print("vv: ", vv)
    env = normalize(GymEnv(vv["env"],record_video=False, record_log=False))

    policy = GaussianMLPPolicy(
        env_spec=env.spec,
        # The neural network policy should have two hidden layers, each with 32 hidden units.
        hidden_sizes=(32, 32)
    )

    baseline = LinearFeatureBaseline(env_spec=env.spec)
    returns = []
    total_iter = vv["total_iter"]
    test_iter = 10
    num_iters = int(total_iter/test_iter)
    
    for i in range(0,num_iters):
        print("iter: ", i)
        
        algo = TRPO(
            env=env,
            policy=policy,
            baseline=baseline,
            batch_size=4000,
            max_path_length=1000,
            n_itr=test_iter,
            discount=0.99,
            step_size=0.01,
    #         Uncomment both lines (this and the plot parameter below) to enable plotting
    #         plot=True,
        )
        algo.train()
        
        ################### Testing in GT parameter #################
        print("mass: ", env.wrapped_env.env.env.model.body_mass)
        
        env2 = copy.deepcopy(env)
        mb = env2.wrapped_env.env.env.model.body_mass
        mb = np.array(mb)
        mb = mb*0.6
        env2.wrapped_env.env.env.model.body_mass = mb

        print("mass: ", env2.wrapped_env.env.env.model.body_mass)

        algo_real = copy.deepcopy(algo)
        algo_real.env = env2
        sampler_cls = BatchSampler
        sampler = sampler_cls(algo_real)
        sampler.start_worker()
        paths = sampler.obtain_samples(1)
        paths_returns = [sum(path["rewards"]) for path in paths]
        sampler.shutdown_worker()
        print("Real sample ave returns: \n\n\n\n\n\n !!!!!!!!!!!!!!!!!!!", np.mean(paths_returns))   
        returns.append(np.mean(paths_returns))
        
        
        path = rollout(env2, algo.policy, max_path_length=1000,
                       animated=False, speedup=1)
        path["returns"] = sum(path["rewards"])
        print("rollout return: \n\n\n\n\n\n\n\n !!!!!!!!!!!!!!!!!!!!!", path["returns"] )
#         returns.append(path['returns'])
        ##############################################################
        
        
    print("returns: ", returns)
    now = datetime.now()
    save_data_filename = "SIM_returns_"+vv["env"]+"_iter_"+str(total_iter)+"_"+str(now)
    with open(save_data_filename, 'wb') as f:
        pickle.dump(returns, f)

variants = VG().variants()


for v in variants:
    run_experiment_lite(
        run_task,
        # Number of parallel workers for sampling
        n_parallel=1,
        # Only keep the snapshot parameters for the last iteration
        snapshot_mode="last",
        # Specifies the seed for the experiment. If this is not provided, a random seed
        # will be used
        seed=v["seed"],
        mode="local",
        exp_prefix = "SIM_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
        variant=v,
    #     plot=True,
    )
# Out:
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0039'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0039'  --variant_data ''  --seed '1'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0040'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0040'  --variant_data ''  --seed '2'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0041'  --log_dir '/home/zhusj/repos/rllab/data/local/SIM-trpo-Swimmer-v1-32-32-4000-iter-400/SIM_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0041'  --variant_data ''  --seed '3'  --use_cloudpickle 'True'  --n_parallel '1'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-eec3940680b7> in <module>()
#      89         mode="local",
#      90         exp_prefix = "SIM_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
# ---> 91         variant=v,
#      92     #     plot=True,
#      93     )
#
# /home/zhusj/repos/rllab/rllab/misc/instrument.py in run_experiment_lite(stub_method_call, batch_tasks, exp_prefix, exp_name, log_dir, script, python_command, mode, dry, docker_image, aws_config, env, variant, use_gpu, sync_s3_pkl, sync_s3_png, sync_s3_log, sync_log_on_termination, confirm_remote, terminate_machine, periodic_sync, periodic_sync_interval, sync_all_data_node_to_s3, use_cloudpickle, pre_commands, added_project_directories, **kwargs)
#     492                     env = dict()
#     493                 subprocess.call(
# --> 494                     command, shell=True, env=dict(os.environ, **env))
#     495             except Exception as e:
#     496                 print(e)
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in call(timeout, *popenargs, **kwargs)
#     557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
# --> 559             return p.wait(timeout=timeout)
#     560         except:
#     561             p.kill()
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in wait(self, timeout, endtime)
#    1656                         if self.returncode is not None:
#    1657                             break  # Another thread waited.
# -> 1658                         (pid, sts) = self._try_wait(0)
#    1659                         # Check the pid and loop as waitpid has been known to
#    1660                         # return 0 even without WNOHANG in odd situations.
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in _try_wait(self, wait_flags)
#    1606             """All callers to this function MUST hold self._waitpid_lock."""
#    1607             try:
# -> 1608                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1609             except ChildProcessError:
#    1610                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
############### real = 0.6 * default

############## Train in real env ########################

def run_task(vv):
    # Please note that different environments with different action spaces may
    # require different policies. For example with a Discrete action space, a
    # CategoricalMLPPolicy works, but for a Box action space may need to use
    # a GaussianMLPPolicy (see the trpo_gym_pendulum.py example)
    print("vv: ", vv)
    env_real = normalize(GymEnv(vv["env"],record_video=False, record_log=False))
    
    print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
    
    mb = env_real.wrapped_env.env.env.model.body_mass
    mb = np.array(mb)
    mb = mb*0.6
    env_real.wrapped_env.env.env.model.body_mass = mb
    print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
    
    
    policy = GaussianMLPPolicy(
        env_spec=env_real.spec,
        # The neural network policy should have two hidden layers, each with 32 hidden units.
        hidden_sizes=(32, 32)
    )

    baseline = LinearFeatureBaseline(env_spec=env_real.spec)
    returns = []
    total_iter = vv["total_iter"]
    test_iter = 10
    num_iters = int(total_iter/test_iter)
    
    for i in range(0,num_iters):
        print("iter: ", i)
        
        algo = TRPO(
            env=env_real,
            policy=policy,
            baseline=baseline,
            batch_size=4000,
            max_path_length=1000,
            n_itr=test_iter,
            discount=0.99,
            step_size=0.01,
    #         Uncomment both lines (this and the plot parameter below) to enable plotting
    #         plot=True,
        )
        algo.train()
        
        ################### Testing in GT parameter #################
        print("real mass: ", env_real.wrapped_env.env.env.model.body_mass)
        
#         env2 = copy.deepcopy(env)
#         mb = env2.wrapped_env.env.env.model.body_mass
#         mb = np.array(mb)
#         mb = mb*0.6
#         env2.wrapped_env.env.env.model.body_mass = mb

#         print("real mass: ", env2.wrapped_env.env.env.model.body_mass)

#         path = rollout(env2, policy, max_path_length=1000,
#                        animated=False, speedup=1)

        path = rollout(env_real, policy, max_path_length=1000,
                       animated=False, speedup=1)
        path["returns"] = sum(path["rewards"])
        print("returns: ", path['returns'])
        returns.append(path['returns'])
        ##############################################################
        
        
    print("returns: ", returns)
    now = datetime.now()
    save_data_filename = "REAL_returns_"+vv["env"]+"_iter_"+str(total_iter)+"_"+str(now)
    with open(save_data_filename, 'wb') as f:
        pickle.dump(returns, f)
        
    
variants = VG().variants()

for v in variants:
    run_experiment_lite(
        run_task,
        # Number of parallel workers for sampling
        n_parallel=1,
        # Only keep the snapshot parameters for the last iteration
        snapshot_mode="last",
        # Specifies the seed for the experiment. If this is not provided, a random seed
        # will be used
        seed=v["seed"],
        exp_prefix = "REAL_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
        variant=v,
    #     plot=True,
    )
# Out:
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0044'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0044'  --variant_data ''  --seed '1'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0045'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0045'  --variant_data ''  --seed '2'  --use_cloudpickle 'True'  --n_parallel '1'
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --snapshot_mode 'last'  --exp_name 'REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0046'  --log_dir '/home/zhusj/repos/rllab/data/local/REAL-trpo-Swimmer-v1-32-32-4000-iter-400/REAL_trpo_Swimmer-v1_32_32_4000_iter_400_2017_09_06_11_24_59_0046'  --variant_data ''  --seed '3'  --use_cloudpickle 'True'  --n_parallel '1'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-4bd45e73cf74> in <module>()
#      89         seed=v["seed"],
#      90         exp_prefix = "REAL_trpo_"+v["env"]+"_32_32_4000_iter_"+str(v["total_iter"]),
# ---> 91         variant=v,
#      92     #     plot=True,
#      93     )
#
# /home/zhusj/repos/rllab/rllab/misc/instrument.py in run_experiment_lite(stub_method_call, batch_tasks, exp_prefix, exp_name, log_dir, script, python_command, mode, dry, docker_image, aws_config, env, variant, use_gpu, sync_s3_pkl, sync_s3_png, sync_s3_log, sync_log_on_termination, confirm_remote, terminate_machine, periodic_sync, periodic_sync_interval, sync_all_data_node_to_s3, use_cloudpickle, pre_commands, added_project_directories, **kwargs)
#     492                     env = dict()
#     493                 subprocess.call(
# --> 494                     command, shell=True, env=dict(os.environ, **env))
#     495             except Exception as e:
#     496                 print(e)
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in call(timeout, *popenargs, **kwargs)
#     557     with Popen(*popenargs, **kwargs) as p:
#     558         try:
# --> 559             return p.wait(timeout=timeout)
#     560         except:
#     561             p.kill()
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in wait(self, timeout, endtime)
#    1656                         if self.returncode is not None:
#    1657                             break  # Another thread waited.
# -> 1658                         (pid, sts) = self._try_wait(0)
#    1659                         # Check the pid and loop as waitpid has been known to
#    1660                         # return 0 even without WNOHANG in odd situations.
#
# /home/zhusj/anaconda2/envs/rllab3/lib/python3.5/subprocess.py in _try_wait(self, wait_flags)
#    1606             """All callers to this function MUST hold self._waitpid_lock."""
#    1607             try:
# -> 1608                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1609             except ChildProcessError:
#    1610                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
datafile =  '../../data/local/trpo-Swimmer-v1-32-32-4000-40/trpo_Swimmer-v1_32_32_4000_40_2017_09_05_18_37_21_0015/progress.csv'
df = pd.read_csv(datafile)
trace1 = go.Scatter(
                    y=df['AverageReturn'], # Data
                    mode='lines', name='training' # Additional options
                   )
trace２ = go.Scatter(
                    y=np.array([20.202899152265687, 11.770700709886349, 21.400652194445151, 25.354204357634103, 20.553359266759884, 22.836364003706514, 22.404311541517821, 22.305505271388089, 23.721623681697373, 20.799683421540408]), # Data
                    mode='lines', name='testing (mass*0.6)' # Additional options
                   )
layout = go.Layout(title='Inverted Pendulum TRPO Perfomance',
                   plot_bgcolor='rgb(230, 230,230)')

fig = go.Figure(data=[trace1, trace2], layout=layout)

# Plot data in the notebook
plotly.offline.iplot(fig)
# Out:
# <div id="16fc42f6-e26a-49a4-bf0d-6404e7e3d5b2" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16fc42f6-e26a-49a4-bf0d-6404e7e3d5b2", [{"mode": "lines", "type": "scatter", "y": [14.6900358953, 18.7748619572, 19.8818168857, 20.6268881963, 20.3850410602, 20.1251959571, 20.2768022317, 22.1736201959, 20.933383540999998, 19.7689221403], "name": "training"}, {"mode": "lines", "type": "scatter", "y": [20.202899152265687, 11.770700709886349, 21.40065219444515, 25.354204357634103, 20.553359266759884, 22.836364003706514, 22.40431154151782, 22.30550527138809, 23.721623681697373, 20.799683421540408], "name": "testing (mass*0.6)"}], {"plot_bgcolor": "rgb(230, 230,230)", "title": "Inverted Pendulum TRPO Perfomance"}, {"linkText": "Export to plot.ly", "showLink": true})</script>

# %%
def run_task(*_):
    # Please note that different environments with different action spaces may
    # require different policies. For example with a Discrete action space, a
    # CategoricalMLPPolicy works, but for a Box action space may need to use
    # a GaussianMLPPolicy (see the trpo_gym_pendulum.py example)
    env = normalize(GymEnv("InvertedPendulum-v1",record_video=False))

    policy = GaussianMLPPolicy(
        env_spec=env.spec,
        # The neural network policy should have two hidden layers, each with 32 hidden units.
        hidden_sizes=(32, 32)
    )

    baseline = LinearFeatureBaseline(env_spec=env.spec)
    returns = []
    total_ier = 100
    test_iter = 10
    num_iters = int(total_ier/test_iter)
    
    for i in range(0,num_iters):
        print("iter: ", i)
        
        ################### Testing in different parameter #################
        print("mass: ", env.wrapped_env.env.env.env.model.body_mass)
        
        env2 = copy.deepcopy(env)
        mb = env2.wrapped_env.env.env.env.model.body_mass
        mb = np.array(mb)
        mb[2,0] = mb[2,0]*0.6
        env2.wrapped_env.env.env.env.model.body_mass = mb

        print("mass: ", env2.wrapped_env.env.env.env.model.body_mass)

        path = rollout(env2, policy, max_path_length=1000,
                       animated=False, speedup=1)
        path["returns"] = sum(path["rewards"])
        returns.append(path['returns'])
        #################################################
        
        algo = TRPO(
            env=env,
            policy=policy,
            baseline=baseline,
            batch_size=4000,
            max_path_length=env.horizon,
            n_itr=test_iter,
            discount=0.99,
            step_size=0.01,
    #         Uncomment both lines (this and the plot parameter below) to enable plotting
    #         plot=True,
        )
        algo.train()
    print("returns: ", returns)


run_experiment_lite(
    run_task,
    # Number of parallel workers for sampling
    n_parallel=8,
    # Only keep the snapshot parameters for the last iteration
    snapshot_mode="last",
    # Specifies the seed for the experiment. If this is not provided, a random seed
    # will be used
    seed=1,
    exp_prefix = "trpo_ip_32_32_4000_100"
#     plot=True,
)
# Out:
# python /home/zhusj/repos/rllab/scripts/run_experiment_lite.py  --args_data '...'  --log_dir '/home/zhusj/repos/rllab/data/local/trpo-ip-32-32-4000-100/trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0005'  --n_parallel '8'  --use_cloudpickle 'True'  --snapshot_mode 'last'  --variant_data 'gAN9cQBYCAAAAGV4cF9uYW1lcQFYLwAAAHRycG9faXBfMzJfMzJfNDAwMF8xMDBfMjAxN18wOV8wNV8xN180OF8zN18wMDA1cQJzLg=='  --seed '1'  --exp_name 'trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0005'

# %%
datafile =  '../../data/local/trpo-ip-32-32-4000-100/trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0002/progress.csv'
df = pd.read_csv(datafile)
trace1 = go.Scatter(
                    y=df['AverageReturn'], # Data
                    mode='lines', name='training' # Additional options
                   )
trace２ = go.Scatter(
                    y=np.array([10.0, 4.0, 5.0, 4.0, 3.0, 12.0, 30.0, 66.0, 15.0, 45.0, 78.0, 102.0, 29.0, 55.0, 81.0, 115.0, 133.0, 103.0, 166.0, 170.0, 154.0, 26.0, 486.0, 1000.0, 306.0, 283.0, 819.0, 394.0, 478.0, 524.0, 873.0, 893.0, 1000.0, 1000.0, 802.0, 293.0, 1000.0, 1000.0, 224.0, 604.0]), # Data
                    mode='lines', name='testing (mass*0.6)' # Additional options
                   )
layout = go.Layout(title='Inverted Pendulum TRPO Perfomance',
                   plot_bgcolor='rgb(230, 230,230)')

fig = go.Figure(data=[trace1, trace2], layout=layout)

# Plot data in the notebook
plotly.offline.iplot(fig)
# Out:
# <div id="c3aea3a5-fd7a-4403-9115-ed94a8996495" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c3aea3a5-fd7a-4403-9115-ed94a8996495", [{"type": "scatter", "mode": "lines", "y": [4.11946446962, 4.5158013544, 5.258869908019999, 5.55833333333, 6.82593856655, 7.71290944123, 10.088161209099999, 13.422818791900001, 20.2171717172, 22.604519774, 30.803030303000003, 45.8522727273, 58.0142857143, 77.6226415094, 90.42222222219999, 108.540540541, 119.82352941200001, 149.740740741, 157.307692308, 148.321428571, 176.826086957, 247.529411765, 349.91666666699996, 522.5, 504.75, 359.91666666699996, 743.333333333, 546.25, 831.2, 754.5, 894.8, 920.4, 853.6, 808.666666667, 1000.0, 737.333333333, 1000.0, 1000.0, 1000.0, 1000.0], "name": "training"}, {"type": "scatter", "mode": "lines", "y": [10.0, 4.0, 5.0, 4.0, 3.0, 12.0, 30.0, 66.0, 15.0, 45.0, 78.0, 102.0, 29.0, 55.0, 81.0, 115.0, 133.0, 103.0, 166.0, 170.0, 154.0, 26.0, 486.0, 1000.0, 306.0, 283.0, 819.0, 394.0, 478.0, 524.0, 873.0, 893.0, 1000.0, 1000.0, 802.0, 293.0, 1000.0, 1000.0, 224.0, 604.0], "name": "testing (mass*0.6)"}], {"title": "Inverted Pendulum TRPO Perfomance", "plot_bgcolor": "rgb(230, 230,230)"}, {"showLink": true, "linkText": "Export to plot.ly"})</script>

# %%
datafile =  '../../data/local/trpo-ip-32-32-4000-100/trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0002/progress.csv'
df = pd.read_csv(datafile)
trace1 = go.Scatter(
                    y=df['AverageReturn'], # Data
                    mode='lines', name='training' # Additional options
                   )
trace２ = go.Scatter(
                    x=np.array([1:10:100])
                    y=np.array([10.0, 4.0, 5.0, 4.0, 3.0, 12.0, 30.0, 66.0, 15.0, 45.0, 78.0, 102.0, 29.0, 55.0, 81.0, 115.0, 133.0, 103.0, 166.0, 170.0, 154.0, 26.0, 486.0, 1000.0, 306.0, 283.0, 819.0, 394.0, 478.0, 524.0, 873.0, 893.0, 1000.0, 1000.0, 802.0, 293.0, 1000.0, 1000.0, 224.0, 604.0]), # Data
                    mode='lines', name='testing (mass*0.6)' # Additional options
                   )
layout = go.Layout(title='Inverted Pendulum TRPO Perfomance',
                   plot_bgcolor='rgb(230, 230,230)')

fig = go.Figure(data=[trace1, trace2], layout=layout)

# Plot data in the notebook
plotly.offline.iplot(fig)

# %%
datafile =  '../../data/local/trpo-ip-32-32-4000-100/trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0003/progress.csv'
df = pd.read_csv(datafile)
trace1 = go.Scatter(
                    y=df['AverageReturn'], # Data
                    mode='lines', name='training' # Additional options
                   )
trace２ = go.Scatter(
                    y = np.array([11.0, 4.0, 3.0, 5.0, 5.0, 7.0, 31.0, 35.0, 6.0, 50.0, 79.0, 92.0, 38.0, 62.0, 144.0, 139.0, 163.0, 136.0, 94.0, 15.0, 225.0, 228.0, 443.0, 283.0, 805.0, 68.0, 761.0, 1000.0, 52.0, 1000.0, 1000.0, 694.0, 1000.0, 1000.0, 744.0, 1000.0, 1000.0, 7.0, 72.0, 1000.0, 594.0, 1000.0, 214.0, 110.0, 1000.0, 565.0, 185.0, 557.0, 246.0, 1000.0, 1000.0, 280.0, 545.0, 1000.0, 1000.0, 1000.0, 451.0, 857.0, 255.0, 312.0, 462.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 325.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 462.0, 549.0, 1000.0, 233.0, 1000.0, 1000.0, 1000.0, 733.0]
),
                    mode='lines', name='testing (mass*0.6)' # Additional options
                   )
layout = go.Layout(title='Inverted Pendulum TRPO Perfomance',
                   plot_bgcolor='rgb(230, 230,230)')

fig = go.Figure(data=[trace1, trace2], layout=layout)

# Plot data in the notebook
plotly.offline.iplot(fig)
# Out:
# <div id="ce0f66c5-d54c-4769-b62e-3fddfaa3d30c" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ce0f66c5-d54c-4769-b62e-3fddfaa3d30c", [{"type": "scatter", "mode": "lines", "y": [4.092024539880001, 4.55922551253, 4.87332521315, 5.56606397775, 6.71308724832, 8.42315789474, 10.258974359, 13.7965517241, 21.1308900524, 23.8452380952, 31.7421875, 42.9468085106, 57.928571428599994, 72.8571428571, 87.52173913040001, 102.71794871799999, 128.75, 151.851851852, 190.136363636, 266.647058824, 395.181818182, 336.75, 661.285714286, 802.0, 674.833333333, 294.1875, 907.6, 840.2, 813.0, 1000.0, 733.333333333, 889.6, 798.666666667, 846.6, 739.666666667, 813.5, 913.6, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 477.0, 789.666666667, 805.833333333, 1000.0, 643.0, 596.857142857, 1000.0, 822.8, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 933.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 673.666666667, 1000.0, 964.6, 1000.0, 811.2, 1000.0, 881.4, 1000.0, 1000.0, 1000.0, 894.2, 1000.0, 1000.0, 1000.0, 966.6, 1000.0, 957.6, 717.166666667, 1000.0, 811.4, 1000.0, 1000.0, 1000.0, 774.833333333], "name": "training"}, {"type": "scatter", "mode": "lines", "y": [11.0, 4.0, 3.0, 5.0, 5.0, 7.0, 31.0, 35.0, 6.0, 50.0, 79.0, 92.0, 38.0, 62.0, 144.0, 139.0, 163.0, 136.0, 94.0, 15.0, 225.0, 228.0, 443.0, 283.0, 805.0, 68.0, 761.0, 1000.0, 52.0, 1000.0, 1000.0, 694.0, 1000.0, 1000.0, 744.0, 1000.0, 1000.0, 7.0, 72.0, 1000.0, 594.0, 1000.0, 214.0, 110.0, 1000.0, 565.0, 185.0, 557.0, 246.0, 1000.0, 1000.0, 280.0, 545.0, 1000.0, 1000.0, 1000.0, 451.0, 857.0, 255.0, 312.0, 462.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 325.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 462.0, 549.0, 1000.0, 233.0, 1000.0, 1000.0, 1000.0, 733.0], "name": "testing (mass*0.6)"}], {"title": "Inverted Pendulum TRPO Perfomance", "plot_bgcolor": "rgb(230, 230,230)"}, {"showLink": true, "linkText": "Export to plot.ly"})</script>

# %%
datafile =  '../../data/local/trpo-ip-32-32-4000-100/trpo_ip_32_32_4000_100_2017_09_05_17_48_37_0001/progress.csv'
df = pd.read_csv(datafile)
trace1 = go.Scatter(
                    y=df['AverageReturn'], # Data
                    mode='lines', name='logx' # Additional options
                   )
layout = go.Layout(title='Simple Plot from csv data',
                   plot_bgcolor='rgb(230, 230,230)')

fig = go.Figure(data=[trace1], layout=layout)

# Plot data in the notebook
plotly.offline.iplot(fig)
# Out:
# <div id="71de2780-8e96-4eb1-accd-130ec7e5fffd" style="height: 525; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("71de2780-8e96-4eb1-accd-130ec7e5fffd", [{"type": "scatter", "mode": "lines", "y": [4.08784473953, 4.588302752290001, 5.370469798659999, 5.757183908049999, 6.80272108844, 7.74274661509, 9.81617647059, 11.614492753599999, 17.4847161572, 21.978021978, 29.419117647100002, 40.5858585859, 52.1558441558, 77.1730769231, 94.3488372093, 95.6904761905, 117.11428571399999, 138.4, 228.11111111099999, 284.066666667, 440.3, 784.5, 939.0, 682.5, 852.4, 1000.0, 833.166666667, 880.0, 1000.0, 699.857142857, 1000.0, 578.857142857, 1000.0, 812.6, 864.2, 1000.0, 925.8, 973.6, 1000.0, 1000.0], "name": "logx"}], {"title": "Simple Plot from csv data", "plot_bgcolor": "rgb(230, 230,230)"}, {"showLink": true, "linkText": "Export to plot.ly"})</script>
